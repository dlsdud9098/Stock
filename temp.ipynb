# %%
import requests
from fake_useragent import UserAgent
import pandas as pd

# %%
pd.read_csv('asdf.csv', encoding='utf-8')
# Out:
#                                             title  \
# 0                        AI 상용화 원년 밝았다…DX를 넘어 AX로
# 1            [공모주달력]2024년 IPO 개시…첫 타자 포스뱅크·스튜디오삼익
# 2                 [신약 R&D 트렌드]주사·경구·패치 등 비만치료제 열풍
# 3    [격동의 황제주⑤] '2023 전세계 상승률 1위' 에코프로, 그 영광은 언제?
# 4              올해도 공모주 청약 이어진다…'몸값 조(兆) 단위' 기대주는?
# ..                                            ...
# 250           [신년사] 이순호 예탁원장 "올해 디지털 혁신 등에 매진할 것"
# 251           [신년사] 이순호 예탁원장 "올해 디지털 혁신 등에 매진할 것"
# 252                 2024년에 주목해야 할 뉴욕 증시의 5가지 테마는?
# 253                 2024년에 주목해야 할 뉴욕 증시의 5가지 테마는?
# 254                      [그래픽] 최근 PF-ABCP 등급별 거래량
#
#                             writer                  date  \
# 0    나원식 (setisoul@bizwatch.co.kr)   2024.01.01. 오전 6:51
# 1         최성준 (csj@bizwatch.co.kr)   2024.01.01. 오전 8:01
# 2      권미란 (rani19@bizwatch.co.kr)  2024.01.01. 오전 10:01
# 3             윤정원(garden@tf.co.kr)  2024.01.01. 오전 12:01
# 4             윤정원(garden@tf.co.kr)  2024.01.01. 오전 12:01
# ...
